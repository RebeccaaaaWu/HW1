# %% [markdown]
# ## Find Frequency Distributions with NLTK (1)

# %% [markdown]
# #### Kernel: Python 2

# %% [markdown]
# Today we will be learning how to use the Natural Language Toolkit (NLTK) module to perform basic text analysis.
#
# NLTK is a Python add-on package which has multiple useful functions for analyzing text files. One key component of text analysis is finding keyword frequency distributions.
#
# A frequency distribution can be shown as a table containing how many times within a document different words appear. To directly quote the NLTK book, “it’s called a "distribution" because it tells us how the total number of word tokens in the text are distributed across the vocabulary items. Since we often need frequency distributions in language processing, NLTK provides built-in support for them” (http://www.nltk.org/book/ch01.html).
#
# Let’s get started.

# %% [markdown]
# ### Lab1:
# 1. String Manipulation
# 2. tokenization
# 3. stop words removal
#
# ### Lab2:
# 3. stemming
# 4. POS
# 5. N-grams
# 6. Tfidf

# %% [markdown]
# ## String Manipulation

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
s = '  Hello '
s
# Out:
# '  Hello '

# %%
s = s.strip()
s
# Out:
# 'Hello'

# %%
#string indexing 
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# 'o'

# %%
s[:4]
# Out:
# 'Hell'

# %%
s = s.lower()
s
# Out:
# 'hello'

# %%
s.isalpha()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
s = 'http:\\www.abc.com'
s.startswith('http')
# Out:
# True

# %%
s = 'I love coding'
s_list = s.split() #default deliminator is ' '(space) 
s_list
# Out:
# ['I', 'love', 'coding']

# %%
new_string = '$$'.join(s_list)
new_string
# Out:
# 'I$$love$$coding'

# %%
s.replace(' ','')
# Out:
# 'Ilovecoding'

# %% [markdown]
# ## Read data

# %%
# install add-on Natural Language Processing toolkit
# you only need to run it once in your device
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/peiyaowu/.local/lib/python3.8/site-packages (3.6.3)
# Requirement already satisfied: click in /Users/peiyaowu/opt/anaconda3/lib/python3.8/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /Users/peiyaowu/opt/anaconda3/lib/python3.8/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex in /Users/peiyaowu/opt/anaconda3/lib/python3.8/site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in /Users/peiyaowu/opt/anaconda3/lib/python3.8/site-packages (from nltk) (4.62.3)

# %%
import nltk
from nltk import FreqDist

#read file from local

#method 1
f = open('input.txt','rb')
raw = f.read()
raw = raw.decode('utf8') #decode raw text by utf-8

#method 2
f = open('input.txt','r+')
raw = f.read()

# %%
type (raw)
# Out:
# str

# %%
raw = raw.replace('\n',' ')

# %% [markdown]
# ## Tokenization

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/peiyaowu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
#change all tokens into lower case 
words1 = [w.lower() for w in tokens]   #list comprehension 

#only keep text words, no numbers 
words2 = [w for w in words1 if w.isalpha()]

# %%
#another way to create a new list: 
words1 = []
for w in tokens: 
    words1.append(w.lower())

# %%
#generate a frequency dictionary for all tokens 
freq = FreqDist(words2)

#sort the frequency list in descending order
sorted_freq = sorted(freq.items(),key = lambda k:k[1], reverse = True)
sorted_freq
# Out:
# [('the', 163978),
#  ('i', 88054),
#  ('and', 79796),
#  ('a', 74657),
#  ('to', 73526),
#  ('is', 52932),
#  ('it', 51505),
#  ('of', 44182),
#  ('camera', 43970),
#  ('for', 35835),
#  ('this', 34021),
#  ('with', 33925),
#  ('you', 33634),
#  ('in', 32506),
#  ('that', 29854),
#  ('my', 23395),
#  ('have', 23055),
#  ('on', 20708),
#  ('but', 20496),
#  ('not', 17820),
#  ('are', 16348),
#  ('as', 16111),
#  ('was', 15144),
#  ('lens', 13704),
#  ('be', 13293),
#  ('if', 12085),
#  ('at', 11937),
#  ('can', 11899),
#  ('so', 11385),
#  ('canon', 10862),
#  ('nikon', 10775),
#  ('or', 10743),
#  ('very', 10700),
#  ('do', 10349),
#  ('more', 10215),
#  ('all', 10118),
#  ('use', 10113),
#  ('great', 9934),
#  ('an', 9225),
#  ('from', 9151),
#  ('has', 9133),
#  ('will', 9130),
#  ('good', 8571),
#  ('get', 8541),
#  ('like', 8533),
#  ('me', 8441),
#  ('one', 8312),
#  ('just', 8247),
#  ('quality', 8089),
#  ('than', 8011),
#  ('about', 7997),
#  ('pictures', 7909),
#  ('out', 7744),
#  ('when', 7665),
#  ('lenses', 7657),
#  ('would', 7384),
#  ('had', 7181),
#  ('some', 6828),
#  ('which', 6410),
#  ('better', 6373),
#  ('up', 6331),
#  ('your', 6198),
#  ('only', 6165),
#  ('also', 5962),
#  ('there', 5956),
#  ('am', 5904),
#  ('cameras', 5839),
#  ('much', 5807),
#  ('no', 5678),
#  ('really', 5642),
#  ('they', 5604),
#  ('digital', 5604),
#  ('what', 5504),
#  ('take', 5393),
#  ('time', 5272),
#  ('iso', 5261),
#  ('even', 5193),
#  ('dslr', 5136),
#  ('video', 5079),
#  ('other', 5031),
#  ('well', 5030),
#  ('shoot', 5026),
#  ('been', 4956),
#  ('focus', 4807),
#  ('now', 4581),
#  ('still', 4549),
#  ('used', 4514),
#  ('image', 4504),
#  ('flash', 4487),
#  ('does', 4479),
#  ('shots', 4460),
#  ('by', 4457),
#  ('light', 4447),
#  ('using', 4419),
#  ('photos', 4329),
#  ('price', 4296),
#  ('first', 4274),
#  ('shooting', 4191),
#  ('mode', 4134),
#  ('slr', 4129),
#  ('new', 4090),
#  ('want', 4082),
#  ('because', 3985),
#  ('its', 3972),
#  ('any', 3955),
#  ('did', 3938),
#  ('after', 3897),
#  ('features', 3845),
#  ('buy', 3795),
#  ('most', 3755),
#  ('point', 3726),
#  ('photography', 3703),
#  ('over', 3659),
#  ('many', 3644),
#  ('need', 3604),
#  ('body', 3591),
#  ('battery', 3509),
#  ('then', 3502),
#  ('easy', 3498),
#  ('images', 3462),
#  ('manual', 3428),
#  ('kit', 3427),
#  ('could', 3413),
#  ('love', 3380),
#  ('bought', 3280),
#  ('best', 3277),
#  ('picture', 3184),
#  ('settings', 3150),
#  ('go', 3081),
#  ('lot', 3058),
#  ('high', 3004),
#  ('how', 2976),
#  ('little', 2951),
#  ('low', 2919),
#  ('too', 2908),
#  ('same', 2869),
#  ('see', 2829),
#  ('auto', 2822),
#  ('them', 2805),
#  ('make', 2777),
#  ('were', 2762),
#  ('lcd', 2735),
#  ('sensor', 2730),
#  ('into', 2729),
#  ('got', 2724),
#  ('shutter', 2711),
#  ('shot', 2711),
#  ('think', 2686),
#  ('pentax', 2682),
#  ('two', 2649),
#  ('rebel', 2646),
#  ('while', 2644),
#  ('back', 2621),
#  ('who', 2601),
#  ('sony', 2595),
#  ('screen', 2579),
#  ('years', 2571),
#  ('nice', 2548),
#  ('say', 2547),
#  ('since', 2533),
#  ('excellent', 2533),
#  ('noise', 2530),
#  ('work', 2508),
#  ('few', 2481),
#  ('way', 2478),
#  ('right', 2469),
#  ('know', 2457),
#  ('without', 2406),
#  ('before', 2386),
#  ('fast', 2366),
#  ('far', 2364),
#  ('view', 2343),
#  ('recommend', 2327),
#  ('card', 2295),
#  ('find', 2231),
#  ('however', 2228),
#  ('those', 2228),
#  ('film', 2218),
#  ('taking', 2210),
#  ('these', 2200),
#  ('both', 2186),
#  ('looking', 2180),
#  ('speed', 2169),
#  ('feature', 2152),
#  ('zoom', 2137),
#  ('around', 2124),
#  ('look', 2106),
#  ('their', 2104),
#  ('amazing', 2093),
#  ('thing', 2090),
#  ('takes', 2083),
#  ('should', 2071),
#  ('full', 2071),
#  ('ca', 2043),
#  ('amazon', 2039),
#  ('money', 2029),
#  ('off', 2028),
#  ('bit', 2028),
#  ('problem', 2025),
#  ('we', 2020),
#  ('people', 2011),
#  ('raw', 2001),
#  ('going', 1998),
#  ('set', 1987),
#  ('feel', 1986),
#  ('old', 1952),
#  ('never', 1949),
#  ('live', 1944),
#  ('getting', 1933),
#  ('af', 1932),
#  ('reviews', 1928),
#  ('happy', 1913),
#  ('photographer', 1911),
#  ('olympus', 1910),
#  ('big', 1902),
#  ('though', 1901),
#  ('professional', 1897),
#  ('enough', 1879),
#  ('small', 1870),
#  ('took', 1868),
#  ('found', 1867),
#  ('may', 1855),
#  ('long', 1855),
#  ('made', 1850),
#  ('range', 1843),
#  ('review', 1838),
#  ('viewfinder', 1837),
#  ('able', 1833),
#  ('taken', 1811),
#  ('photo', 1784),
#  ('less', 1778),
#  ('makes', 1739),
#  ('having', 1732),
#  ('purchased', 1730),
#  ('every', 1726),
#  ('down', 1726),
#  ('purchase', 1723),
#  ('pretty', 1705),
#  ('button', 1691),
#  ('system', 1685),
#  ('size', 1678),
#  ('things', 1653),
#  ('performance', 1646),
#  ('sure', 1615),
#  ('results', 1613),
#  ('works', 1602),
#  ('read', 1596),
#  ('another', 1590),
#  ('upgrade', 1584),
#  ('where', 1583),
#  ('something', 1578),
#  ('almost', 1567),
#  ('second', 1563),
#  ('exposure', 1542),
#  ('wanted', 1532),
#  ('quite', 1529),
#  ('being', 1528),
#  ('here', 1525),
#  ('level', 1518),
#  ('through', 1514),
#  ('autofocus', 1513),
#  ('control', 1508),
#  ('always', 1504),
#  ('different', 1502),
#  ('such', 1498),
#  ('everything', 1485),
#  ('worth', 1474),
#  ('color', 1464),
#  ('setting', 1459),
#  ('between', 1444),
#  ('day', 1441),
#  ('buying', 1428),
#  ('ever', 1419),
#  ('came', 1419),
#  ('extra', 1404),
#  ('perfect', 1394),
#  ('learn', 1386),
#  ('again', 1383),
#  ('pro', 1377),
#  ('especially', 1370),
#  ('come', 1369),
#  ('hands', 1369),
#  ('months', 1366),
#  ('expensive', 1358),
#  ('compared', 1351),
#  ('higher', 1348),
#  ('several', 1324),
#  ('sharp', 1314),
#  ('menu', 1310),
#  ('etc', 1308),
#  ('own', 1304),
#  ('difference', 1301),
#  ('life', 1294),
#  ('overall', 1290),
#  ('yet', 1286),
#  ('comes', 1280),
#  ('user', 1278),
#  ('already', 1275),
#  ('fine', 1274),
#  ('modes', 1254),
#  ('probably', 1231),
#  ('decided', 1229),
#  ('why', 1225),
#  ('focusing', 1223),
#  ('actually', 1219),
#  ('change', 1215),
#  ('last', 1215),
#  ('give', 1213),
#  ('issue', 1213),
#  ('controls', 1207),
#  ('resolution', 1207),
#  ('feels', 1205),
#  ('hand', 1198),
#  ('frame', 1196),
#  ('year', 1193),
#  ('put', 1185),
#  ('grip', 1184),
#  ('seems', 1175),
#  ('software', 1173),
#  ('days', 1172),
#  ('might', 1169),
#  ('highly', 1158),
#  ('white', 1153),
#  ('although', 1124),
#  ('away', 1118),
#  ('xsi', 1111),
#  ('product', 1106),
#  ('large', 1100),
#  ('end', 1098),
#  ('owned', 1097),
#  ('said', 1089),
#  ('options', 1084),
#  ('http', 1084),
#  ('built', 1081),
#  ('balance', 1078),
#  ('aperture', 1077),
#  ('once', 1075),
#  ('ii', 1075),
#  ('memory', 1072),
#  ('keep', 1067),
#  ('wo', 1064),
#  ('mark', 1052),
#  ('learning', 1036),
#  ('bad', 1030),
#  ('weight', 1029),
#  ('anyone', 1025),
#  ('available', 1025),
#  ('ago', 1017),
#  ('couple', 1012),
#  ('eos', 996),
#  ('real', 994),
#  ('awesome', 994),
#  ('function', 992),
#  ('instead', 968),
#  ('choice', 968),
#  ('start', 961),
#  ('thought', 960),
#  ('experience', 959),
#  ('finally', 957),
#  ('ability', 956),
#  ('deal', 953),
#  ('anything', 951),
#  ('faster', 951),
#  ('buttons', 950),
#  ('cost', 935),
#  ('fact', 934),
#  ('top', 930),
#  ('quick', 929),
#  ('least', 928),
#  ('xti', 928),
#  ('hard', 924),
#  ('next', 923),
#  ('try', 923),
#  ('model', 918),
#  ('definitely', 915),
#  ('either', 913),
#  ('larger', 908),
#  ('smaller', 908),
#  ('line', 908),
#  ('times', 907),
#  ('compact', 900),
#  ('solid', 899),
#  ('went', 896),
#  ('fantastic', 896),
#  ('easily', 895),
#  ('under', 891),
#  ('quickly', 888),
#  ('problems', 888),
#  ('let', 888),
#  ('xt', 885),
#  ('hd', 880),
#  ('myself', 878),
#  ('means', 876),
#  ('plus', 875),
#  ('pics', 874),
#  ('simply', 873),
#  ('course', 872),
#  ('tried', 872),
#  ('capture', 870),
#  ('wide', 867),
#  ('clear', 866),
#  ('spend', 857),
#  ('important', 855),
#  ('serious', 851),
#  ('weeks', 850),
#  ('cards', 845),
#  ('box', 840),
#  ('batteries', 839),
#  ('bright', 836),
#  ('nothing', 836),
#  ('dslrs', 832),
#  ('amateur', 829),
#  ('until', 829),
#  ('cheap', 821),
#  ('situations', 819),
#  ('close', 818),
#  ('reason', 817),
#  ('hold', 816),
#  ('points', 808),
#  ('vr', 807),
#  ('started', 806),
#  ('three', 802),
#  ('wonderful', 802),
#  ('needs', 800),
#  ('value', 799),
#  ('detail', 796),
#  ('build', 779),
#  ('world', 777),
#  ('slow', 777),
#  ('doing', 776),
#  ('update', 774),
#  ('reading', 773),
#  ('others', 769),
#  ('unless', 766),
#  ('display', 766),
#  ('extremely', 765),
#  ('must', 765),
#  ('lighting', 762),
#  ('allows', 760),
#  ('needed', 760),
#  ('huge', 759),
#  ('side', 759),
#  ('functions', 756),
#  ('tripod', 756),
#  ('market', 756),
#  ('colors', 755),
#  ('mp', 754),
#  ('help', 754),
#  ('class', 752),
#  ('sports', 751),
#  ('making', 749),
#  ('done', 748),
#  ('maybe', 744),
#  ('useful', 742),
#  ('pleased', 742),
#  ('switch', 742),
#  ('format', 734),
#  ('conditions', 731),
#  ('advanced', 730),
#  ('automatic', 730),
#  ('metering', 729),
#  ('our', 727),
#  ('issues', 722),
#  ('turn', 719),
#  ('heavy', 715),
#  ('wait', 712),
#  ('true', 711),
#  ('research', 711),
#  ('rather', 709),
#  ('night', 709),
#  ('often', 707),
#  ('models', 705),
#  ('megapixels', 700),
#  ('disappointed', 697),
#  ('dust', 697),
#  ('gives', 694),
#  ('menus', 694),
#  ('yes', 694),
#  ('sd', 693),
#  ('wish', 692),
#  ('impressed', 692),
#  ('stabilization', 691),
#  ('he', 691),
#  ('files', 690),
#  ('believe', 683),
#  ('each', 682),
#  ('fun', 682),
#  ('tell', 680),
#  ('macro', 679),
#  ('standard', 678),
#  ('trying', 675),
#  ('due', 671),
#  ('reduction', 671),
#  ('month', 668),
#  ('above', 667),
#  ('per', 666),
#  ('wrong', 666),
#  ('field', 666),
#  ('absolutely', 664),
#  ('consider', 661),
#  ('short', 659),
#  ('someone', 657),
#  ('dx', 656),
#  ('series', 656),
#  ('older', 652),
#  ('action', 652),
#  ('entry', 649),
#  ('shoots', 648),
#  ('slightly', 647),
#  ('lower', 646),
#  ('fps', 645),
#  ('case', 644),
#  ('easier', 643),
#  ('simple', 637),
#  ('glass', 636),
#  ('subject', 635),
#  ('pros', 634),
#  ('photographers', 633),
#  ('looked', 631),
#  ('family', 630),
#  ('sometimes', 630),
#  ('computer', 630),
#  ('option', 629),
#  ('else', 628),
#  ('cons', 623),
#  ('similar', 622),
#  ('capabilities', 621),
#  ('decent', 620),
#  ('felt', 620),
#  ('job', 614),
#  ('week', 614),
#  ('beautiful', 613),
#  ('later', 613),
#  ('looks', 613),
#  ('beginner', 612),
#  ('understand', 612),
#  ('expect', 609),
#  ('jpeg', 608),
#  ('including', 606),
#  ('dial', 602),
#  ('moving', 602),
#  ('add', 602),
#  ('seem', 596),
#  ('included', 595),
#  ('var', 594),
#  ('bigger', 592),
#  ('lots', 591),
#  ('upgraded', 587),
#  ('seen', 586),
#  ('service', 586),
#  ('save', 582),
#  ('photoshop', 575),
#  ('super', 575),
#  ('order', 573),
#  ('number', 573),
#  ('frames', 571),
#  ('minolta', 571),
#  ('recently', 570),
#  ('step', 566),
#  ('improved', 565),
#  ('stars', 564),
#  ('past', 563),
#  ('cheaper', 563),
#  ('longer', 562),
#  ('main', 562),
#  ('previous', 561),
#  ('considering', 559),
#  ('continuous', 559),
#  ('during', 558),
#  ('opinion', 558),
#  ('mm', 557),
#  ('offers', 556),
#  ('part', 554),
#  ('plastic', 553),
#  ('mind', 552),
#  ('outstanding', 551),
#  ('move', 549),
#  ('telephoto', 549),
#  ('uses', 548),
#  ('along', 545),
#  ('capability', 544),
#  ('equipment', 543),
#  ('l', 542),
#  ('pixels', 542),
#  ('soon', 538),
#  ('mostly', 538),
#  ('slrs', 538),
#  ('itself', 537),
#  ('pay', 537),
#  ('accurate', 531),
#  ('users', 530),
#  ('carry', 530),
#  ('mine', 528),
#  ('fit', 527),
#  ('processing', 526),
#  ('received', 526),
#  ('comfortable', 526),
#  ('adjust', 525),
#  ('coming', 525),
#  ('sharpness', 524),
#  ('limited', 523),
#  ('check', 521),
#  ('power', 520),
#  ('ease', 518),
#  ('wife', 517),
#  ('recording', 515),
#  ('technology', 515),
#  ('expected', 514),
#  ('test', 513),
#  ('advantage', 510),
#  ('movie', 508),
#  ('store', 508),
#  ('working', 507),
#  ('dark', 506),
#  ('external', 505),
#  ('brand', 505),
#  ('package', 505),
#  ('completely', 504),
#  ('sigma', 502),
#  ('bag', 501),
#  ('compare', 500),
#  ('kind', 499),
#  ('nikkor', 497),
#  ('remote', 494),
#  ('us', 494),
#  ('left', 494),
#  ('decision', 494),
#  ('basic', 492),
#  ('glad', 492),
#  ('depth', 492),
#  ('type', 491),
#  ('indoor', 491),
#  ('matter', 490),
#  ('friends', 490),
#  ('single', 490),
#  ('sold', 489),
#  ('eye', 486),
#  ('rate', 485),
#  ('lack', 485),
#  ('anyway', 484),
#  ('improvement', 483),
#  ('angle', 481),
#  ('videos', 481),
#  ('superb', 480),
#  ('return', 479),
#  ('crop', 479),
#  ('possible', 478),
#  ('portrait', 477),
#  ('usually', 477),
#  ('iii', 476),
#  ('note', 475),
#  ('hope', 473),
#  ('half', 472),
#  ('various', 467),
#  ('satisfied', 466),
#  ('megapixel', 465),
#  ('prime', 465),
#  ('release', 462),
#  ('additional', 460),
#  ('worked', 460),
#  ('allow', 458),
#  ('cf', 457),
#  ('mirror', 457),
#  ('lighter', 456),
#  ('based', 456),
#  ('bodies', 455),
#  ('weather', 454),
#  ('manually', 454),
#  ('stop', 452),
#  ('ok', 452),
#  ('spent', 451),
#  ('major', 450),
#  ('support', 449),
#  ('nearly', 448),
#  ('p', 448),
#  ('she', 447),
#  ('incredible', 447),
#  ('except', 445),
#  ('gets', 444),
#  ('added', 444),
#  ('yourself', 443),
#  ('leica', 443),
#  ('difficult', 442),
#  ('within', 442),
#  ('filter', 442),
#  ('program', 441),
#  ('choose', 440),
#  ('intuitive', 440),
#  ('purchasing', 440),
#  ('helps', 439),
#  ('budget', 439),
#  ('pixel', 438),
#  ('play', 438),
#  ('fully', 438),
#  ('turned', 438),
#  ('dynamic', 437),
#  ('black', 437),
#  ('panasonic', 436),
#  ('online', 434),
#  ('whole', 433),
#  ('truly', 433),
#  ('trip', 433),
#  ('thinking', 431),
#  ('enjoy', 430),
#  ('spot', 428),
#  ('firmware', 428),
#  ('today', 426),
#  ('kids', 425),
#  ('noticed', 425),
#  ('produces', 425),
#  ('contrast', 425),
#  ('ones', 423),
#  ('print', 423),
#  ('sound', 421),
#  ('prefer', 421),
#  ('loved', 420),
#  ('amount', 419),
#  ('accessories', 418),
#  ('factor', 417),
#  ('charge', 417),
#  ('given', 417),
#  ('friend', 415),
#  ('design', 415),
#  ('scene', 414),
#  ('care', 414),
#  ('gave', 413),
#  ('landscape', 412),
#  ('show', 412),
#  ('fixed', 412),
#  ('focal', 412),
#  ('capable', 411),
#  ('photographs', 411),
#  ('customer', 411),
#  ('his', 410),
#  ('version', 409),
#  ('creative', 407),
#  ('lense', 406),
#  ('offer', 405),
#  ('home', 405),
#  ('free', 405),
#  ('portraits', 405),
#  ('ordered', 404),
#  ('warranty', 402),
#  ('perfectly', 401),
#  ('example', 401),
#  ('goes', 399),
#  ('mount', 399),
#  ('plan', 398),
#  ('liked', 398),
#  ('become', 397),
#  ('nikons', 397),
#  ('ef', 397),
#  ('piece', 397),
#  ('ergonomics', 396),
#  ('ready', 395),
#  ('shipping', 395),
#  ('prints', 395),
#  ('four', 393),
#  ('file', 392),
#  ('custom', 391),
#  ('front', 391),
#  ('starting', 391),
#  ('poor', 390),
#  ('terms', 388),
#  ('addition', 387),
#  ('waiting', 387),
#  ('comparison', 386),
#  ('details', 386),
#  ('recommended', 386),
#  ('pick', 385),
#  ('produce', 384),
#  ('area', 384),
#  ('shake', 381),
#  ('everyone', 380),
#  ('press', 379),
#  ('motor', 378),
#  ('person', 377),
#  ('plenty', 377),
#  ('bottom', 376),
#  ('post', 376),
#  ('fairly', 374),
#  ('otherwise', 374),
#  ('indoors', 373),
#  ('guess', 373),
#  ('hdr', 372),
#  ('exactly', 371),
#  ('editing', 371),
#  ('finder', 370),
#  ('miss', 370),
#  ('newer', 370),
#  ('normal', 367),
#  ('filters', 365),
#  ('stuff', 365),
#  ('reasons', 364),
#  ('cool', 364),
#  ('superior', 364),
#  ('certainly', 363),
#  ('crisp', 362),
#  ('original', 360),
#  ('replacement', 359),
#  ('figure', 358),
#  ('remember', 358),
#  ('priority', 358),
#  ('beyond', 358),
#  ('whether', 355),
#  ('forward', 355),
#  ('returned', 354),
#  ('information', 354),
#  ('unit', 353),
#  ('chose', 353),
#  ('clean', 351),
#  ('knew', 350),
#  ('future', 350),
#  ('please', 349),
#  ('technical', 349),
#  ('list', 349),
#  ('place', 349),
#  ('repair', 349),
#  ('fits', 348),
#  ('tamron', 348),
#  ('error', 346),
#  ('open', 345),
#  ('minutes', 345),
#  ('run', 344),
#  ('alpha', 344),
#  ('burst', 343),
#  ('hours', 342),
#  ('called', 340),
#  ('changing', 340),
#  ('length', 339),
#  ('impressive', 338),
#  ('afford', 337),
#  ('fix', 337),
#  ('soft', 336),
#  ('suggest', 336),
#  ('wedding', 336),
#  ('inside', 335),
#  ('general', 334),
#  ('somewhat', 334),
#  ('mean', 333),
#  ('upgrading', 332),
#  ('her', 332),
#  ('handy', 331),
#  ('subjects', 330),
#  ('products', 330),
#  ('handle', 330),
#  ('minor', 329),
#  ('christmas', 329),
#  ('usable', 328),
#  ('brands', 328),
#  ('center', 327),
#  ('playing', 327),
#  ('book', 327),
#  ('holding', 326),
#  ('xs', 326),
#  ('helpful', 325),
#  ('designed', 325),
#  ('experienced', 325),
#  ('notice', 323),
#  ('wants', 321),
#  ('likely', 320),
#  ('multiple', 319),
#  ('interested', 319),
#  ('wow', 318),
#  ('room', 317),
#  ('seemed', 317),
#  ('missing', 317),
#  ('heavier', 316),
#  ('seconds', 316),
#  ('paid', 316),
#  ('equivalent', 316),
#  ('relatively', 315),
#  ('friendly', 314),
#  ('curve', 314),
#  ('exposures', 314),
#  ('replace', 314),
#  ('current', 312),
#  ('amazed', 312),
#  ('mention', 312),
#  ('preview', 311),
#  ('told', 310),
#  ('basically', 310),
#  ('investment', 309),
#  ('saw', 309),
#  ('record', 309),
#  ('average', 309),
#  ('local', 309),
#  ('red', 308),
#  ('complaints', 308),
#  ('sent', 307),
#  ('star', 306),
#  ('buffer', 306),
#  ('mentioned', 305),
#  ('monitor', 304),
#  ('access', 304),
#  ('regret', 304),
#  ('gotten', 303),
#  ('decide', 303),
#  ('spending', 303),
#  ('handling', 303),
#  ('guide', 302),
#  ('result', 302),
#  ('cover', 301),
#  ('complaint', 301),
#  ('canons', 301),
#  ('vs', 300),
#  ('near', 300),
#  ('speeds', 300),
#  ('write', 299),
#  ('dollars', 299),
#  ('idea', 299),
#  ('certain', 299),
#  ('below', 298),
#  ('send', 298),
#  ('adjustments', 297),
#  ('against', 297),
#  ('stunning', 297),
#  ('biggest', 296),
#  ('usm', 295),
#  ('optical', 295),
#  ('thanks', 295),
#  ('correct', 294),
#  ('happier', 293),
#  ('immediately', 291),
#  ('info', 291),
#  ('default', 291),
#  ('outside', 290),
#  ('comparing', 290),
#  ('leave', 289),
#  ('twice', 289),
#  ('fuji', 288),
#  ('moment', 286),
#  ('nsprefix', 286),
#  ('totally', 285),
#  ('learned', 285),
#  ('item', 285),
#  ('situation', 283),
#  ('saying', 283),
#  ('priced', 283),
#  ('dedicated', 281),
#  ('process', 281),
#  ('perhaps', 281),
#  ('aa', 281),
#  ('compatible', 280),
#  ('third', 280),
#  ('negative', 280),
#  ('surprised', 279),
#  ('wanting', 277),
#  ('considered', 277),
#  ('provides', 277),
#  ('beat', 277),
#  ('comparable', 276),
#  ('lag', 276),
#  ('unlike', 275),
#  ('picked', 275),
#  ('interface', 275),
#  ('selection', 275),
#  ('background', 275),
#  ('slower', 275),
#  ('backup', 275),
#  ('rest', 274),
#  ('personal', 274),
#  ('differences', 273),
#  ('favorite', 273),
#  ('clarity', 273),
#  ('levels', 272),
#  ('changed', 271),
#  ('personally', 271),
#  ('cannon', 271),
#  ('travel', 270),
#  ('five', 270),
#  ('mainly', 269),
#  ('novice', 269),
#  ('beginners', 268),
#  ('cmos', 268),
#  ('sensors', 268),
#  ('affordable', 268),
#  ('hundred', 267),
#  ('face', 267),
#  ('regular', 265),
#  ('extreme', 265),
#  ('viewing', 265),
#  ('fx', 265),
#  ('wireless', 264),
#  ('strap', 264),
#  ('studio', 264),
#  ('selling', 263),
#  ('outdoor', 263),
#  ('stick', 261),
#  ('currently', 261),
#  ('lightweight', 261),
#  ('bracketing', 261),
#  ('jump', 260),
#  ('early', 259),
#  ('shows', 259),
#  ('specs', 259),
#  ('head', 259),
#  ('despite', 259),
#  ('noticeable', 258),
#  ('changes', 257),
#  ...]

# %%
#If the this code does not show a figure, just try to run it twice
freq.plot(30)

# %% [markdown]
# ## Stop words removal

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ricardolu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stopwords = stopwords.words('english') #use the NLTK stopwords

# %%
#only keep the words that not in nltk stopwords word list
words_nostopwords = [w for w in words2 if w not in stopwords]

# %%
#generate a frequency dictionary for all tokens 
freq_nostw = FreqDist(words_nostopwords)

#sort the frequency list in decending order
sorted_freq_nostw = sorted(freq_nostw.items(),key = lambda k:k[1], reverse = True)
sorted_freq_nostw
# Out:
# [('camera', 43970),
#  ('lens', 13704),
#  ('canon', 10862),
#  ('nikon', 10775),
#  ('use', 10113),
#  ('great', 9934),
#  ('good', 8571),
#  ('get', 8541),
#  ('like', 8533),
#  ('one', 8312),
#  ('quality', 8089),
#  ('pictures', 7909),
#  ('lenses', 7657),
#  ('would', 7384),
#  ('better', 6373),
#  ('also', 5962),
#  ('cameras', 5839),
#  ('much', 5807),
#  ('really', 5642),
#  ('digital', 5604),
#  ('take', 5393),
#  ('time', 5272),
#  ('iso', 5261),
#  ('even', 5193),
#  ('dslr', 5136),
#  ('video', 5079),
#  ('well', 5030),
#  ('shoot', 5026),
#  ('focus', 4807),
#  ('still', 4549),
#  ('used', 4514),
#  ('image', 4504),
#  ('flash', 4487),
#  ('shots', 4460),
#  ('light', 4447),
#  ('using', 4419),
#  ('photos', 4329),
#  ('price', 4296),
#  ('first', 4274),
#  ('shooting', 4191),
#  ('mode', 4134),
#  ('slr', 4129),
#  ('new', 4090),
#  ('want', 4082),
#  ('features', 3845),
#  ('buy', 3795),
#  ('point', 3726),
#  ('photography', 3703),
#  ('many', 3644),
#  ('need', 3604),
#  ('body', 3591),
#  ('battery', 3509),
#  ('easy', 3498),
#  ('images', 3462),
#  ('manual', 3428),
#  ('kit', 3427),
#  ('could', 3413),
#  ('love', 3380),
#  ('bought', 3280),
#  ('best', 3277),
#  ('picture', 3184),
#  ('settings', 3150),
#  ('go', 3081),
#  ('lot', 3058),
#  ('high', 3004),
#  ('little', 2951),
#  ('low', 2919),
#  ('see', 2829),
#  ('auto', 2822),
#  ('make', 2777),
#  ('lcd', 2735),
#  ('sensor', 2730),
#  ('got', 2724),
#  ('shutter', 2711),
#  ('shot', 2711),
#  ('think', 2686),
#  ('pentax', 2682),
#  ('two', 2649),
#  ('rebel', 2646),
#  ('back', 2621),
#  ('sony', 2595),
#  ('screen', 2579),
#  ('years', 2571),
#  ('nice', 2548),
#  ('say', 2547),
#  ('since', 2533),
#  ('excellent', 2533),
#  ('noise', 2530),
#  ('work', 2508),
#  ('way', 2478),
#  ('right', 2469),
#  ('know', 2457),
#  ('without', 2406),
#  ('fast', 2366),
#  ('far', 2364),
#  ('view', 2343),
#  ('recommend', 2327),
#  ('card', 2295),
#  ('find', 2231),
#  ('however', 2228),
#  ('film', 2218),
#  ('taking', 2210),
#  ('looking', 2180),
#  ('speed', 2169),
#  ('feature', 2152),
#  ('zoom', 2137),
#  ('around', 2124),
#  ('look', 2106),
#  ('amazing', 2093),
#  ('thing', 2090),
#  ('takes', 2083),
#  ('full', 2071),
#  ('ca', 2043),
#  ('amazon', 2039),
#  ('money', 2029),
#  ('bit', 2028),
#  ('problem', 2025),
#  ('people', 2011),
#  ('raw', 2001),
#  ('going', 1998),
#  ('set', 1987),
#  ('feel', 1986),
#  ('old', 1952),
#  ('never', 1949),
#  ('live', 1944),
#  ('getting', 1933),
#  ('af', 1932),
#  ('reviews', 1928),
#  ('happy', 1913),
#  ('photographer', 1911),
#  ('olympus', 1910),
#  ('big', 1902),
#  ('though', 1901),
#  ('professional', 1897),
#  ('enough', 1879),
#  ('small', 1870),
#  ('took', 1868),
#  ('found', 1867),
#  ('may', 1855),
#  ('long', 1855),
#  ('made', 1850),
#  ('range', 1843),
#  ('review', 1838),
#  ('viewfinder', 1837),
#  ('able', 1833),
#  ('taken', 1811),
#  ('photo', 1784),
#  ('less', 1778),
#  ('makes', 1739),
#  ('purchased', 1730),
#  ('every', 1726),
#  ('purchase', 1723),
#  ('pretty', 1705),
#  ('button', 1691),
#  ('system', 1685),
#  ('size', 1678),
#  ('things', 1653),
#  ('performance', 1646),
#  ('sure', 1615),
#  ('results', 1613),
#  ('works', 1602),
#  ('read', 1596),
#  ('another', 1590),
#  ('upgrade', 1584),
#  ('something', 1578),
#  ('almost', 1567),
#  ('second', 1563),
#  ('exposure', 1542),
#  ('wanted', 1532),
#  ('quite', 1529),
#  ('level', 1518),
#  ('autofocus', 1513),
#  ('control', 1508),
#  ('always', 1504),
#  ('different', 1502),
#  ('everything', 1485),
#  ('worth', 1474),
#  ('color', 1464),
#  ('setting', 1459),
#  ('day', 1441),
#  ('buying', 1428),
#  ('ever', 1419),
#  ('came', 1419),
#  ('extra', 1404),
#  ('perfect', 1394),
#  ('learn', 1386),
#  ('pro', 1377),
#  ('especially', 1370),
#  ('come', 1369),
#  ('hands', 1369),
#  ('months', 1366),
#  ('expensive', 1358),
#  ('compared', 1351),
#  ('higher', 1348),
#  ('several', 1324),
#  ('sharp', 1314),
#  ('menu', 1310),
#  ('etc', 1308),
#  ('difference', 1301),
#  ('life', 1294),
#  ('overall', 1290),
#  ('yet', 1286),
#  ('comes', 1280),
#  ('user', 1278),
#  ('already', 1275),
#  ('fine', 1274),
#  ('modes', 1254),
#  ('probably', 1231),
#  ('decided', 1229),
#  ('focusing', 1223),
#  ('actually', 1219),
#  ('change', 1215),
#  ('last', 1215),
#  ('give', 1213),
#  ('issue', 1213),
#  ('controls', 1207),
#  ('resolution', 1207),
#  ('feels', 1205),
#  ('hand', 1198),
#  ('frame', 1196),
#  ('year', 1193),
#  ('put', 1185),
#  ('grip', 1184),
#  ('seems', 1175),
#  ('software', 1173),
#  ('days', 1172),
#  ('might', 1169),
#  ('highly', 1158),
#  ('white', 1153),
#  ('although', 1124),
#  ('away', 1118),
#  ('xsi', 1111),
#  ('product', 1106),
#  ('large', 1100),
#  ('end', 1098),
#  ('owned', 1097),
#  ('said', 1089),
#  ('options', 1084),
#  ('http', 1084),
#  ('built', 1081),
#  ('balance', 1078),
#  ('aperture', 1077),
#  ('ii', 1075),
#  ('memory', 1072),
#  ('keep', 1067),
#  ('wo', 1064),
#  ('mark', 1052),
#  ('learning', 1036),
#  ('bad', 1030),
#  ('weight', 1029),
#  ('anyone', 1025),
#  ('available', 1025),
#  ('ago', 1017),
#  ('couple', 1012),
#  ('eos', 996),
#  ('real', 994),
#  ('awesome', 994),
#  ('function', 992),
#  ('instead', 968),
#  ('choice', 968),
#  ('start', 961),
#  ('thought', 960),
#  ('experience', 959),
#  ('finally', 957),
#  ('ability', 956),
#  ('deal', 953),
#  ('anything', 951),
#  ('faster', 951),
#  ('buttons', 950),
#  ('cost', 935),
#  ('fact', 934),
#  ('top', 930),
#  ('quick', 929),
#  ('least', 928),
#  ('xti', 928),
#  ('hard', 924),
#  ('next', 923),
#  ('try', 923),
#  ('model', 918),
#  ('definitely', 915),
#  ('either', 913),
#  ('larger', 908),
#  ('smaller', 908),
#  ('line', 908),
#  ('times', 907),
#  ('compact', 900),
#  ('solid', 899),
#  ('went', 896),
#  ('fantastic', 896),
#  ('easily', 895),
#  ('quickly', 888),
#  ('problems', 888),
#  ('let', 888),
#  ('xt', 885),
#  ('hd', 880),
#  ('means', 876),
#  ('plus', 875),
#  ('pics', 874),
#  ('simply', 873),
#  ('course', 872),
#  ('tried', 872),
#  ('capture', 870),
#  ('wide', 867),
#  ('clear', 866),
#  ('spend', 857),
#  ('important', 855),
#  ('serious', 851),
#  ('weeks', 850),
#  ('cards', 845),
#  ('box', 840),
#  ('batteries', 839),
#  ('bright', 836),
#  ('nothing', 836),
#  ('dslrs', 832),
#  ('amateur', 829),
#  ('cheap', 821),
#  ('situations', 819),
#  ('close', 818),
#  ('reason', 817),
#  ('hold', 816),
#  ('points', 808),
#  ('vr', 807),
#  ('started', 806),
#  ('three', 802),
#  ('wonderful', 802),
#  ('needs', 800),
#  ('value', 799),
#  ('detail', 796),
#  ('build', 779),
#  ('world', 777),
#  ('slow', 777),
#  ('update', 774),
#  ('reading', 773),
#  ('others', 769),
#  ('unless', 766),
#  ('display', 766),
#  ('extremely', 765),
#  ('must', 765),
#  ('lighting', 762),
#  ('allows', 760),
#  ('needed', 760),
#  ('huge', 759),
#  ('side', 759),
#  ('functions', 756),
#  ('tripod', 756),
#  ('market', 756),
#  ('colors', 755),
#  ('mp', 754),
#  ('help', 754),
#  ('class', 752),
#  ('sports', 751),
#  ('making', 749),
#  ('done', 748),
#  ('maybe', 744),
#  ('useful', 742),
#  ('pleased', 742),
#  ('switch', 742),
#  ('format', 734),
#  ('conditions', 731),
#  ('advanced', 730),
#  ('automatic', 730),
#  ('metering', 729),
#  ('issues', 722),
#  ('turn', 719),
#  ('heavy', 715),
#  ('wait', 712),
#  ('true', 711),
#  ('research', 711),
#  ('rather', 709),
#  ('night', 709),
#  ('often', 707),
#  ('models', 705),
#  ('megapixels', 700),
#  ('disappointed', 697),
#  ('dust', 697),
#  ('gives', 694),
#  ('menus', 694),
#  ('yes', 694),
#  ('sd', 693),
#  ('wish', 692),
#  ('impressed', 692),
#  ('stabilization', 691),
#  ('files', 690),
#  ('believe', 683),
#  ('fun', 682),
#  ('tell', 680),
#  ('macro', 679),
#  ('standard', 678),
#  ('trying', 675),
#  ('due', 671),
#  ('reduction', 671),
#  ('month', 668),
#  ('per', 666),
#  ('wrong', 666),
#  ('field', 666),
#  ('absolutely', 664),
#  ('consider', 661),
#  ('short', 659),
#  ('someone', 657),
#  ('dx', 656),
#  ('series', 656),
#  ('older', 652),
#  ('action', 652),
#  ('entry', 649),
#  ('shoots', 648),
#  ('slightly', 647),
#  ('lower', 646),
#  ('fps', 645),
#  ('case', 644),
#  ('easier', 643),
#  ('simple', 637),
#  ('glass', 636),
#  ('subject', 635),
#  ('pros', 634),
#  ('photographers', 633),
#  ('looked', 631),
#  ('family', 630),
#  ('sometimes', 630),
#  ('computer', 630),
#  ('option', 629),
#  ('else', 628),
#  ('cons', 623),
#  ('similar', 622),
#  ('capabilities', 621),
#  ('decent', 620),
#  ('felt', 620),
#  ('job', 614),
#  ('week', 614),
#  ('beautiful', 613),
#  ('later', 613),
#  ('looks', 613),
#  ('beginner', 612),
#  ('understand', 612),
#  ('expect', 609),
#  ('jpeg', 608),
#  ('including', 606),
#  ('dial', 602),
#  ('moving', 602),
#  ('add', 602),
#  ('seem', 596),
#  ('included', 595),
#  ('var', 594),
#  ('bigger', 592),
#  ('lots', 591),
#  ('upgraded', 587),
#  ('seen', 586),
#  ('service', 586),
#  ('save', 582),
#  ('photoshop', 575),
#  ('super', 575),
#  ('order', 573),
#  ('number', 573),
#  ('frames', 571),
#  ('minolta', 571),
#  ('recently', 570),
#  ('step', 566),
#  ('improved', 565),
#  ('stars', 564),
#  ('past', 563),
#  ('cheaper', 563),
#  ('longer', 562),
#  ('main', 562),
#  ('previous', 561),
#  ('considering', 559),
#  ('continuous', 559),
#  ('opinion', 558),
#  ('mm', 557),
#  ('offers', 556),
#  ('part', 554),
#  ('plastic', 553),
#  ('mind', 552),
#  ('outstanding', 551),
#  ('move', 549),
#  ('telephoto', 549),
#  ('uses', 548),
#  ('along', 545),
#  ('capability', 544),
#  ('equipment', 543),
#  ('l', 542),
#  ('pixels', 542),
#  ('soon', 538),
#  ('mostly', 538),
#  ('slrs', 538),
#  ('pay', 537),
#  ('accurate', 531),
#  ('users', 530),
#  ('carry', 530),
#  ('mine', 528),
#  ('fit', 527),
#  ('processing', 526),
#  ('received', 526),
#  ('comfortable', 526),
#  ('adjust', 525),
#  ('coming', 525),
#  ('sharpness', 524),
#  ('limited', 523),
#  ('check', 521),
#  ('power', 520),
#  ('ease', 518),
#  ('wife', 517),
#  ('recording', 515),
#  ('technology', 515),
#  ('expected', 514),
#  ('test', 513),
#  ('advantage', 510),
#  ('movie', 508),
#  ('store', 508),
#  ('working', 507),
#  ('dark', 506),
#  ('external', 505),
#  ('brand', 505),
#  ('package', 505),
#  ('completely', 504),
#  ('sigma', 502),
#  ('bag', 501),
#  ('compare', 500),
#  ('kind', 499),
#  ('nikkor', 497),
#  ('remote', 494),
#  ('us', 494),
#  ('left', 494),
#  ('decision', 494),
#  ('basic', 492),
#  ('glad', 492),
#  ('depth', 492),
#  ('type', 491),
#  ('indoor', 491),
#  ('matter', 490),
#  ('friends', 490),
#  ('single', 490),
#  ('sold', 489),
#  ('eye', 486),
#  ('rate', 485),
#  ('lack', 485),
#  ('anyway', 484),
#  ('improvement', 483),
#  ('angle', 481),
#  ('videos', 481),
#  ('superb', 480),
#  ('return', 479),
#  ('crop', 479),
#  ('possible', 478),
#  ('portrait', 477),
#  ('usually', 477),
#  ('iii', 476),
#  ('note', 475),
#  ('hope', 473),
#  ('half', 472),
#  ('various', 467),
#  ('satisfied', 466),
#  ('megapixel', 465),
#  ('prime', 465),
#  ('release', 462),
#  ('additional', 460),
#  ('worked', 460),
#  ('allow', 458),
#  ('cf', 457),
#  ('mirror', 457),
#  ('lighter', 456),
#  ('based', 456),
#  ('bodies', 455),
#  ('weather', 454),
#  ('manually', 454),
#  ('stop', 452),
#  ('ok', 452),
#  ('spent', 451),
#  ('major', 450),
#  ('support', 449),
#  ('nearly', 448),
#  ('p', 448),
#  ('incredible', 447),
#  ('except', 445),
#  ('gets', 444),
#  ('added', 444),
#  ('leica', 443),
#  ('difficult', 442),
#  ('within', 442),
#  ('filter', 442),
#  ('program', 441),
#  ('choose', 440),
#  ('intuitive', 440),
#  ('purchasing', 440),
#  ('helps', 439),
#  ('budget', 439),
#  ('pixel', 438),
#  ('play', 438),
#  ('fully', 438),
#  ('turned', 438),
#  ('dynamic', 437),
#  ('black', 437),
#  ('panasonic', 436),
#  ('online', 434),
#  ('whole', 433),
#  ('truly', 433),
#  ('trip', 433),
#  ('thinking', 431),
#  ('enjoy', 430),
#  ('spot', 428),
#  ('firmware', 428),
#  ('today', 426),
#  ('kids', 425),
#  ('noticed', 425),
#  ('produces', 425),
#  ('contrast', 425),
#  ('ones', 423),
#  ('print', 423),
#  ('sound', 421),
#  ('prefer', 421),
#  ('loved', 420),
#  ('amount', 419),
#  ('accessories', 418),
#  ('factor', 417),
#  ('charge', 417),
#  ('given', 417),
#  ('friend', 415),
#  ('design', 415),
#  ('scene', 414),
#  ('care', 414),
#  ('gave', 413),
#  ('landscape', 412),
#  ('show', 412),
#  ('fixed', 412),
#  ('focal', 412),
#  ('capable', 411),
#  ('photographs', 411),
#  ('customer', 411),
#  ('version', 409),
#  ('creative', 407),
#  ('lense', 406),
#  ('offer', 405),
#  ('home', 405),
#  ('free', 405),
#  ('portraits', 405),
#  ('ordered', 404),
#  ('warranty', 402),
#  ('perfectly', 401),
#  ('example', 401),
#  ('goes', 399),
#  ('mount', 399),
#  ('plan', 398),
#  ('liked', 398),
#  ('become', 397),
#  ('nikons', 397),
#  ('ef', 397),
#  ('piece', 397),
#  ('ergonomics', 396),
#  ('ready', 395),
#  ('shipping', 395),
#  ('prints', 395),
#  ('four', 393),
#  ('file', 392),
#  ('custom', 391),
#  ('front', 391),
#  ('starting', 391),
#  ('poor', 390),
#  ('terms', 388),
#  ('addition', 387),
#  ('waiting', 387),
#  ('comparison', 386),
#  ('details', 386),
#  ('recommended', 386),
#  ('pick', 385),
#  ('produce', 384),
#  ('area', 384),
#  ('shake', 381),
#  ('everyone', 380),
#  ('press', 379),
#  ('motor', 378),
#  ('person', 377),
#  ('plenty', 377),
#  ('bottom', 376),
#  ('post', 376),
#  ('fairly', 374),
#  ('otherwise', 374),
#  ('indoors', 373),
#  ('guess', 373),
#  ('hdr', 372),
#  ('exactly', 371),
#  ('editing', 371),
#  ('finder', 370),
#  ('miss', 370),
#  ('newer', 370),
#  ('normal', 367),
#  ('filters', 365),
#  ('stuff', 365),
#  ('reasons', 364),
#  ('cool', 364),
#  ('superior', 364),
#  ('certainly', 363),
#  ('crisp', 362),
#  ('original', 360),
#  ('replacement', 359),
#  ('figure', 358),
#  ('remember', 358),
#  ('priority', 358),
#  ('beyond', 358),
#  ('whether', 355),
#  ('forward', 355),
#  ('returned', 354),
#  ('information', 354),
#  ('unit', 353),
#  ('chose', 353),
#  ('clean', 351),
#  ('knew', 350),
#  ('future', 350),
#  ('please', 349),
#  ('technical', 349),
#  ('list', 349),
#  ('place', 349),
#  ('repair', 349),
#  ('fits', 348),
#  ('tamron', 348),
#  ('error', 346),
#  ('open', 345),
#  ('minutes', 345),
#  ('run', 344),
#  ('alpha', 344),
#  ('burst', 343),
#  ('hours', 342),
#  ('called', 340),
#  ('changing', 340),
#  ('length', 339),
#  ('impressive', 338),
#  ('afford', 337),
#  ('fix', 337),
#  ('soft', 336),
#  ('suggest', 336),
#  ('wedding', 336),
#  ('inside', 335),
#  ('general', 334),
#  ('somewhat', 334),
#  ('mean', 333),
#  ('upgrading', 332),
#  ('handy', 331),
#  ('subjects', 330),
#  ('products', 330),
#  ('handle', 330),
#  ('minor', 329),
#  ('christmas', 329),
#  ('usable', 328),
#  ('brands', 328),
#  ('center', 327),
#  ('playing', 327),
#  ('book', 327),
#  ('holding', 326),
#  ('xs', 326),
#  ('helpful', 325),
#  ('designed', 325),
#  ('experienced', 325),
#  ('notice', 323),
#  ('wants', 321),
#  ('likely', 320),
#  ('multiple', 319),
#  ('interested', 319),
#  ('wow', 318),
#  ('room', 317),
#  ('seemed', 317),
#  ('missing', 317),
#  ('heavier', 316),
#  ('seconds', 316),
#  ('paid', 316),
#  ('equivalent', 316),
#  ('relatively', 315),
#  ('friendly', 314),
#  ('curve', 314),
#  ('exposures', 314),
#  ('replace', 314),
#  ('current', 312),
#  ('amazed', 312),
#  ('mention', 312),
#  ('preview', 311),
#  ('told', 310),
#  ('basically', 310),
#  ('investment', 309),
#  ('saw', 309),
#  ('record', 309),
#  ('average', 309),
#  ('local', 309),
#  ('red', 308),
#  ('complaints', 308),
#  ('sent', 307),
#  ('star', 306),
#  ('buffer', 306),
#  ('mentioned', 305),
#  ('monitor', 304),
#  ('access', 304),
#  ('regret', 304),
#  ('gotten', 303),
#  ('decide', 303),
#  ('spending', 303),
#  ('handling', 303),
#  ('guide', 302),
#  ('result', 302),
#  ('cover', 301),
#  ('complaint', 301),
#  ('canons', 301),
#  ('vs', 300),
#  ('near', 300),
#  ('speeds', 300),
#  ('write', 299),
#  ('dollars', 299),
#  ('idea', 299),
#  ('certain', 299),
#  ('send', 298),
#  ('adjustments', 297),
#  ('stunning', 297),
#  ('biggest', 296),
#  ('usm', 295),
#  ('optical', 295),
#  ('thanks', 295),
#  ('correct', 294),
#  ('happier', 293),
#  ('immediately', 291),
#  ('info', 291),
#  ('default', 291),
#  ('outside', 290),
#  ('comparing', 290),
#  ('leave', 289),
#  ('twice', 289),
#  ('fuji', 288),
#  ('moment', 286),
#  ('nsprefix', 286),
#  ('totally', 285),
#  ('learned', 285),
#  ('item', 285),
#  ('situation', 283),
#  ('saying', 283),
#  ('priced', 283),
#  ('dedicated', 281),
#  ('process', 281),
#  ('perhaps', 281),
#  ('aa', 281),
#  ('compatible', 280),
#  ('third', 280),
#  ('negative', 280),
#  ('surprised', 279),
#  ('wanting', 277),
#  ('considered', 277),
#  ('provides', 277),
#  ('beat', 277),
#  ('comparable', 276),
#  ('lag', 276),
#  ('unlike', 275),
#  ('picked', 275),
#  ('interface', 275),
#  ('selection', 275),
#  ('background', 275),
#  ('slower', 275),
#  ('backup', 275),
#  ('rest', 274),
#  ('personal', 274),
#  ('differences', 273),
#  ('favorite', 273),
#  ('clarity', 273),
#  ('levels', 272),
#  ('changed', 271),
#  ('personally', 271),
#  ('cannon', 271),
#  ('travel', 270),
#  ('five', 270),
#  ('mainly', 269),
#  ('novice', 269),
#  ('beginners', 268),
#  ('cmos', 268),
#  ('sensors', 268),
#  ('affordable', 268),
#  ('hundred', 267),
#  ('face', 267),
#  ('regular', 265),
#  ('extreme', 265),
#  ('viewing', 265),
#  ('fx', 265),
#  ('wireless', 264),
#  ('strap', 264),
#  ('studio', 264),
#  ('selling', 263),
#  ('outdoor', 263),
#  ('stick', 261),
#  ('currently', 261),
#  ('lightweight', 261),
#  ('bracketing', 261),
#  ('jump', 260),
#  ('early', 259),
#  ('shows', 259),
#  ('specs', 259),
#  ('head', 259),
#  ('despite', 259),
#  ('noticeable', 258),
#  ('changes', 257),
#  ('events', 257),
#  ('special', 257),
#  ('seeing', 256),
#  ('rating', 255),
#  ('chance', 255),
#  ('adobe', 255),
#  ('competition', 255),
#  ('flashes', 253),
#  ('annoying', 253),
#  ('meter', 253),
#  ('sharper', 252),
#  ('complete', 251),
#  ('hit', 251),
#  ('improve', 250),
#  ('realize', 250),
#  ('ended', 250),
#  ('sell', 250),
#  ('consumer', 249),
#  ('arrived', 249),
#  ('sense', 249),
#  ('areas', 248),
#  ('call', 248),
#  ('hobby', 248),
#  ('natural', 247),
#  ('particular', 247),
#  ('none', 247),
#  ('dont', 246),
#  ('whatever', 246),
#  ('camcorder', 244),
#  ('worry', 244),
#  ('alone', 244),
#  ('lock', 244),
#  ('electronic', 243),
#  ('pocket', 243),
#  ('aware', 243),
#  ('noisy', 243),
#  ('combination', 243),
#  ('iq', 243),
#  ('together', 242),
#  ('provide', 242),
#  ('gear', 241),
#  ('held', 241),
#  ('tool', 241),
#  ('improvements', 241),
#  ('ask', 240),
#  ('giving', 239),
#  ('familiar', 238),
#  ('construction', 237),
#  ('worse', 237),
#  ('useless', 236),
#  ('kept', 236),
#  ('significant', 236),
#  ('expectations', 236),
#  ('ways', 236),
#  ('landscapes', 236),
#  ('produced', 235),
#  ('feeling', 235),
#  ('prices', 234),
#  ('baby', 234),
#  ('particularly', 234),
#  ('x', 234),
#  ('f', 234),
#  ('nature', 234),
#  ('audio', 233),
#  ('compensation', 233),
#  ('forget', 232),
#  ('website', 232),
#  ('mic', 231),
#  ('costs', 231),
#  ('guy', 231),
#  ('offered', 230),
#  ('gone', 230),
#  ('blown', 230),
#  ('effect', 230),
#  ('push', 230),
#  ('doubt', 230),
#  ('oh', 230),
#  ('company', 230),
#  ('placed', 229),
#  ('unfortunately', 229),
#  ('vacation', 229),
#  ('drive', 229),
#  ('web', 229),
#  ('heard', 228),
#  ('de', 228),
#  ('limitations', 228),
#  ('sturdy', 228),
#  ('automatically', 227),
#  ('usb', 227),
#  ('reasonable', 227),
#  ('stock', 227),
#  ('movies', 227),
#  ('hot', 227),
#  ('necessary', 226),
#  ('space', 226),
#  ('create', 225),
#  ('invest', 225),
#  ('sdhc', 225),
#  ('lightroom', 225),
#  ('owner', 225),
#  ('bring', 225),
#  ('processor', 224),
#  ('detailed', 224),
#  ('b', 224),
#  ('performs', 224),
#  ('pack', 224),
#  ('medium', 224),
#  ('adjustment', 223),
#  ('potential', 223),
#  ('clearly', 223),
#  ('site', 223),
#  ...]

# %%
#If the this code does not show a figure, just try to run it twice
freq_nostw.plot(30)

# %% [markdown]
# ## Save the result

# %%
with open ('output.txt','a') as outfile:
    for line in sorted_freq_nostw:
        outfile.write(str(line[0])+'\t'+str(line[1])+'\n')

# %% [markdown]
# All done! Thanks for join me.
